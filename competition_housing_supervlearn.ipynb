# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MaxAbsScaler
from sklearn.decomposition import TruncatedSVD
from sklearn import linear_model
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import RandomizedSearchCV
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn import linear_model
from sklearn.linear_model import PoissonRegressor
house_all = pd.read_csv('train.csv')
house_test=pd.read_csv('test.csv')
house_all.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_all.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
X = house_all.drop(columns=['SalePrice'])
y = house_all['SalePrice']

# Split the dataset into train and test sets
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.05, random_state=42)

# %% [markdown]
# Preprocessor

# %%
# Identify the numerical and categorical columns
num_cols = X.select_dtypes(include='number')
cat_cols = X.select_dtypes(exclude='number')
categorical_pipe = make_pipeline(SimpleImputer(strategy="constant", fill_value="N_A"),OneHotEncoder(handle_unknown='ignore', drop='first'))
num_cols=num_cols.drop('Id', axis=1 )
# Create transformers for numerical and categorical features
num_pipe = make_pipeline(SimpleImputer())


# Create a ColumnTransformer to apply the transformers to the appropriate columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', num_pipe, num_cols.columns),
        ('cat', categorical_pipe, cat_cols.columns)
    ])

# %% [markdown]
# DecisionTreeRegressor

# %%
# Combine the preprocessor and the model into a single pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),('scale',MaxAbsScaler()), ('sele',SelectFromModel(DecisionTreeRegressor())),
    ('model', DecisionTreeRegressor())])


# Fit the pipeline to the training data
pipeline.fit(X_train, y_train)

# Make predictions
y_train_pred_all = pipeline.predict(X_train)
y_test_pred_all = pipeline.predict(X_test)
y_test_pred_test = pipeline.predict(house_test)
# Out:
# c:\Users\piotr\anaconda30\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5, 15, 16, 30, 31, 41] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
from sklearn.metrics import r2_score
performances = pd.DataFrame(columns=["train", "test"])

performances.loc["decision_tree", "train"] = r2_score(y_train, y_train_pred_all)
performances.loc["decision_tree", "test"] = r2_score(y_test, y_test_pred_all)
performances
# Out:
#                  train      test
# decision_tree  0.99999  0.733876

# %% [markdown]
# KNeighborsRegressor- doesnt work, work on it!

# %%
# Combine the preprocessor and the model into a single pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),('scale',MaxAbsScaler()), ('sele',SelectFromModel(KNeighborsRegressor())),
    ('model', KNeighborsRegressor(p=1, n_neighbors=7, weights='distance'))])


# Fit the pipeline to the training data
pipeline.fit(X_train, y_train)

# Make predictions
y_train_pred_all = pipeline.predict(X_train)
y_test_pred_all = pipeline.predict(X_test)
y_test_pred_test = pipeline.predict(house_test)

# %%
from sklearn.metrics import r2_score
performances = pd.DataFrame(columns=["train", "test"])

performances.loc["knn", "train"] = r2_score(y_train, y_train_pred_all)
performances.loc["knn", "test"] = r2_score(y_test, y_test_pred_all)
performances

# %% [markdown]
# GradBoostRegRFECV

# %%
from sklearn.feature_selection import RFECV


# Combine the preprocessor and the model into a single pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),('scale',MaxAbsScaler()),('selefrommod',RFECV(GradientBoostingRegressor())), ('model', GradientBoostingRegressor())
])

# %%
# Fit the pipeline to the training data
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath'...
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object'))])),
#                 ('scale', MaxAbsScaler()),
# ...

# %%
# Make predictions
y_train_pred_all = pipeline.predict(X_train)
y_test_pred_all = pipeline.predict(X_test)
y_test_pred_test1=pipeline.predict(house_test)
from sklearn.metrics import r2_score
performances.loc["RFECF_GradBoostReg", "train"] = r2_score(y_train, y_train_pred_all)
performances.loc["RFECF_GradBoostReg", "test"] = r2_score(y_test, y_test_pred_all)
performances
# Out:
# c:\Users\piotr\anaconda30\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5, 15, 16, 30, 31, 41] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                       train      test
# decision_tree       0.99999  0.733876
# RFECF_GradBoostReg  0.96734  0.899016

# %%
house_test['SalePrice']=y_test_pred_test1
house_submission_df3=house_test.loc[:,['Id','SalePrice']]
house_submission_df3

house_submission_df3.to_csv('submission3.csv', index=False)
house_submission_df3.head()
# Out:
#      Id      SalePrice
# 0  1461  121198.273572
# 1  1462  164215.140726
# 2  1463  175980.999189
# 3  1464  180858.632963
# 4  1465  191716.803245

# %% [markdown]
# GradBoostRegRFECV+paramaters

# %%
from sklearn.model_selection import GridSearchCV


# Combine the preprocessor and the model into a single pipeline, add parameters
pipeline = Pipeline([
    ('preprocessor', preprocessor),('scale',MaxAbsScaler()),('selefrommod',RFECV(GradientBoostingRegressor())), ('model', GradientBoostingRegressor())
])
param_grid = {"columntransformer__num_pipe__simpleimputer": ["mean", "median"],
              'gradientboostingregressor__bootstrap': [True],
              'gradientboostingregressor__max_depth': [10, 20, 40, 100, 150],
              'gradientboostingregressor__max_features': [2, 3,10],
              'gradientboostingregressor__min_samples_leaf': [4, 5,10,20],
              'gradientboostingregressor__min_samples_split': [3, 6, 10, 15]
}
search = GridSearchCV(pipeline,
                             param_grid,
                             cv=20,
                             verbose=1)

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath'...
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object'))])),
#                 ('scale', MaxAbsScaler()),
# ...

# %%
# Make predictions
y_train_pred_all = pipeline.predict(X_train)
y_test_pred_all = pipeline.predict(X_test)
y_test_pred_test1=pipeline.predict(house_test)
from sklearn.metrics import r2_score
performances.loc["RFECV_GradBoostReg_grid", "train"] = r2_score(y_train, y_train_pred_all)
performances.loc["RFECV_GradBoostReg_grid", "test"] = r2_score(y_test, y_test_pred_all)
performances
# Out:
# c:\Users\piotr\anaconda30\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5, 15, 16, 30, 31, 41] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             train      test
# decision_tree             0.99999  0.733876
# RFECF_GradBoostReg        0.96734  0.899016
# RFECV_GradBoostReg_grid  0.967299  0.903288

# %%
house_test['SalePrice']=y_test_pred_test1
house_submission_df4=house_test.loc[:,['Id','SalePrice']]
house_submission_df4

house_submission_df4.to_csv('submission4.csv', index=False)
house_submission_df4.head()
# Out:
#      Id      SalePrice
# 0  1461  120926.596230
# 1  1462  164109.356459
# 2  1463  176607.461519
# 3  1464  182204.976443
# 4  1465  190984.487000

# %% [markdown]
# GradienBoostingRegressor_Selectfrommodel

# %%
# Combine the preprocessor and the model into a single pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),('scale',MaxAbsScaler()),('selfrommod',SelectFromModel(GradientBoostingRegressor())),
    ('model', GradientBoostingRegressor())
])
from sklearn.model_selection import GridSearchCV

param_grid = {"columntransformer__num_pipe__simpleimputer": ["mean", "median"],
              'gradientboostingregressor__bootstrap': [True],
              'gradientboostingregressor__max_depth': [20, 40, 100, 150],
              'gradientboostingregressor__max_features': [2, 3,10],
              'gradientboostingregressor__min_samples_leaf': [4, 5,10,20],
              'gradientboostingregressor__min_samples_split': [3,6, 10, 15],
              'gradientboostingregressor__n_estimators': [100, 200, 300, 1000]}
search = GridSearchCV(pipeline,
                             param_grid,
                             cv=20,
                             verbose=1)

# %%
# Fit the pipeline to the training data
pipeline.fit(X_train, y_train)


# Make predictions
y_train_pred_all = pipeline.predict(X_train)
y_test_pred_all = pipeline.predict(X_test)
y_test_pred_test = pipeline.predict(house_test)



from sklearn.metrics import r2_score
performances.loc["grid_selfrommod_GBR", "train"] = r2_score(y_train, y_train_pred_all)
performances.loc["grid_selfrommod_GBR", "test"] = r2_score(y_test, y_test_pred_all)
performances
# Out:
# c:\Users\piotr\anaconda30\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5, 15, 16, 30, 31, 41] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             train      test
# decision_tree             0.99999  0.733876
# RFECF_GradBoostReg        0.96734  0.899016
# RFECV_GradBoostReg_grid  0.967299  0.903288
# grid_selfrommod_GBR      0.957804  0.888648

# %%
house_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN        Gar2   12500
# 2         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         HLS    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
house_test['SalePrice']=y_test_pred_test
house_submission_df=house_test.loc[:,['Id','SalePrice']]
house_submission_df

house_submission_df.to_csv('submission.csv', index=False)
house_submission_df.head()
# Out:
#      Id      SalePrice
# 0  1461  129128.684869
# 1  1462  156481.310250
# 2  1463  178766.799913
# 3  1464  182863.792648
# 4  1465  199809.950084

# %% [markdown]
# Truncated_GradientBoostingRegressor()

# %%
#
# Combine the preprocessor and the model into a single pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),('scale',MaxAbsScaler()), ('svd', TruncatedSVD(n_components=5)),
    ('model', GradientBoostingRegressor())])
param_grid = {"columntransformer__num_pipe__simpleimputer": ["mean", "median"],
}
search = GridSearchCV(pipeline,
                             param_grid,
                             cv=20,
                             verbose=1)

# %%
# Fit the pipeline to the training data
pipeline.fit(X_train, y_train)

# Make predictions
y_train_pred_all = pipeline.predict(X_train)
y_test_pred_all = pipeline.predict(X_test)
from sklearn.metrics import r2_score

performances.loc["truncated_gradBoostReg", "train"] = r2_score(y_train, y_train_pred_all)
performances.loc["truncated_gradBoostReg", "test"] = r2_score(y_test, y_test_pred_all)
performances
# Out:
#                             train      test
# decision_tree             0.99999  0.733876
# RFECF_GradBoostReg        0.96734  0.899016
# RFECV_GradBoostReg_grid  0.967299  0.903288
# grid_selfrommod_GBR      0.957804  0.888648
# truncated_gradBoostReg   0.834601  0.795996

# %% [markdown]
# PoissonRegressor_Selectfrommodel

# %%
from sklearn import linear_model
from sklearn.linear_model import PoissonRegressor



# Combine the preprocessor and the model into a single pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),('scale',MaxAbsScaler()), ('selfrommod',SelectFromModel(PoissonRegressor())),
    ('model', PoissonRegressor())])

param_grid = {"columntransformer__num_pipe__simpleimputer": ["mean", "median"],
}
search = GridSearchCV(pipeline,
                             param_grid,
                             cv=20,
                             verbose=1)

# %%
# Fit the pipeline to the training data
pipeline.fit(X_train, y_train)

# Make predictions
y_train_pred_all = pipeline.predict(X_train)
y_test_pred_all = pipeline.predict(X_test)
y_test_pred_test = pipeline.predict(house_test)
from sklearn.metrics import r2_score

performances.loc["poissonreg_selmodel", "train"] = r2_score(y_train, y_train_pred_all)
performances.loc["poissonreg_selmodel", "test"] = r2_score(y_test, y_test_pred_all)
performances
# Out:
# c:\Users\piotr\anaconda30\lib\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# c:\Users\piotr\anaconda30\lib\site-packages\sklearn\linear_model\_glm\glm.py:284: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res)
# ...

# %%
house_test['SalePrice']=y_test_pred_test
house_submission_df=house_test.loc[:,['Id','SalePrice']]
house_submission_df

house_submission_df.to_csv('hause_submission.csv', index=False)
house_submission_df.head()
# Out:
#      Id      SalePrice
# 0  1461  129698.136594
# 1  1462  170655.709094
# 2  1463  156837.913849
# 3  1464  186100.932305
# 4  1465  224482.924035

# %% [markdown]
# PoissonRegressor_RVECV

# %%
# Combine the preprocessor and the model into a single pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),('scale',MaxAbsScaler()), ('RVECV',RFECV(PoissonRegressor())),
    ('model', PoissonRegressor())])

param_grid = {"columntransformer__num_pipe__simpleimputer": ["mean", "median"],
}
search = GridSearchCV(pipeline,
                             param_grid,
                             cv=20,
                             verbose=1)

# %%
# Fit the pipeline to the training data
pipeline.fit(X_train, y_train)

# %%
# Make predictions
y_train_pred_all = pipeline.predict(X_train)
y_test_pred_all = pipeline.predict(X_test)
y_test_pred_test = pipeline.predict(house_test)
from sklearn.metrics import r2_score

performances.loc["poissonreg_RVECV", "train"] = r2_score(y_train, y_train_pred_all)
performances.loc["poissonreg_RVECV", "test"] = r2_score(y_test, y_test_pred_all)
performances
# Out:
# c:\Users\piotr\anaconda30\lib\site-packages\sklearn\preprocessing\_encoders.py:202: UserWarning: Found unknown categories in columns [0, 5, 15, 16, 30, 31, 41] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#                             train      test
# decision_tree             0.99999  0.733876
# RFECF_GradBoostReg        0.96734  0.899016
# RFECV_GradBoostReg_grid  0.967299  0.903288
# grid_selfrommod_GBR      0.957804  0.888648
# truncated_gradBoostReg   0.834601  0.795996
# poissonreg_selmodel      0.911826   0.91576
# poissonreg_RVECV         0.937333  0.922177

# %%
house_test['SalePrice']=y_test_pred_test

# %%
house_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN        Gar2   12500
# 2         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         HLS    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition      SalePrice
# ...

# %%
house_submission_df1=house_test.loc[:,['Id','SalePrice']]
house_submission_df1

house_submission_df1.to_csv('hause_submission2.csv', index=False)
house_submission_df1.head()
# Out:
#      Id      SalePrice
# 0  1461  119508.990537
# 1  1462  157181.508338
# 2  1463  172324.326393
# 3  1464  195736.876295
# 4  1465  206738.820717
